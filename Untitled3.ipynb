# %% [markdown]
# <a href="https://colab.research.google.com/github/AashiGarg-tech/My-Portfolio/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
data['species'].value_counts().plot(kind='bar')
plt.show()
